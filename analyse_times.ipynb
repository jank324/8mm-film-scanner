# %%
import pickle

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Full Iteration (RAW)

# %%
with open("times_iteration_raw.pkl", "rb") as f:
    data = pickle.load(f)
frame, capture, advance = zip(*data)

# %%
plt.figure(figsize=(10,10))
plt.subplot(311)
plt.title("Full Iteration (RAW)")
plt.plot(frame, label="All")
plt.plot(capture, label="Capture + DNG")
plt.plot(advance, label="Advance")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.ylim([0, None])
plt.legend()
plt.grid()
plt.subplot(312)
plt.title(f"Capture + DNG (mean: {np.mean(capture):.3f}, std: {np.std(capture):.3f})")
plt.plot(capture, c="tab:orange")
m, b = np.polyfit(range(len(data)), capture, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:blue", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(313)
plt.title(f"Advance (mean: {np.mean(advance):.3f}, std: {np.std(advance):.3f})")
plt.plot(advance, c="tab:green")
m, b = np.polyfit(range(len(data)), advance, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:red", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Full Iteration (RAW) - Second Attempt

# %%
with open("times_iteration_raw_2.pkl", "rb") as f:
    data = pickle.load(f)
iteration = [sample["tit"] for sample in data]
capture = [sample["tc"] for sample in data]
advance = [sample["ta"] for sample in data]

# %%
plt.figure(figsize=(10,10))
plt.subplot(311)
plt.title("Full Iteration (RAW) - Second Attempt")
plt.plot(iteration, label="All")
plt.plot(capture, label="Capture + DNG")
plt.plot(advance, label="Advance")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.ylim([0, None])
plt.legend()
plt.grid()
plt.subplot(312)
plt.title(f"Capture + DNG (mean: {np.mean(capture):.3f}, std: {np.std(capture):.3f})")
plt.plot(capture, c="tab:orange")
m, b = np.polyfit(range(len(data)), capture, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:blue", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(313)
plt.title(f"Advance (mean: {np.mean(advance):.3f}, std: {np.std(advance):.3f})")
plt.plot(advance, c="tab:green")
m, b = np.polyfit(range(len(data)), advance, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:red", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Full Iteration (No DNG)

# %%
with open("times_iteration_nodng.pkl", "rb") as f:
    data = pickle.load(f)
iteration = [sample["tit"] for sample in data]
capture = [sample["tc"] for sample in data]
advance = [sample["ta"] for sample in data]

# %%
plt.figure(figsize=(10,10))
plt.subplot(311)
plt.title("Full Iteration (No DNG)")
plt.plot(iteration, label="All")
plt.plot(capture, label="Capture + DNG")
plt.plot(advance, label="Advance")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.ylim([0, None])
plt.legend()
plt.grid()
plt.subplot(312)
plt.title(f"Capture + Write (mean: {np.mean(capture):.3f}, std: {np.std(capture):.3f})")
plt.plot(capture, c="tab:orange")
m, b = np.polyfit(range(len(data)), capture, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:blue", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(313)
plt.title(f"Advance (mean: {np.mean(advance):.3f}, std: {np.std(advance):.3f})")
plt.plot(advance, c="tab:green")
m, b = np.polyfit(range(len(data)), advance, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:red", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Capture (RAW)

# %%
with open("times_capture_raw.pkl", "rb") as f:
    data = pickle.load(f)
full = [sample["tf"] for sample in data]
capture = [sample["tc"] for sample in data]
dng = [sample["tdng"] for sample in data]
write = [sample["tw"] for sample in data]

# %%
plt.figure(figsize=(10,12.5))
plt.subplot(411)
plt.title("Capture (RAW)")
plt.plot(full, label="All")
plt.plot(capture, label="Capture")
plt.plot(dng, label="DNG Conversion")
plt.plot(write, label="Write")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.ylim([0, None])
plt.legend()
plt.grid()
plt.subplot(412)
plt.title(f"Capture (mean: {np.mean(capture):.3f}, std: {np.std(capture):.3f})")
plt.plot(capture, c="tab:orange")
m, b = np.polyfit(range(len(data)), capture, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:blue", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(413)
plt.title(f"DNG Conversion (mean: {np.mean(dng):.3f}, std: {np.std(dng):.3f})")
plt.plot(dng, c="tab:green")
m, b = np.polyfit(range(len(data)), dng, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:red", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(414)
plt.title(f"Write (mean: {np.mean(write):.3f}, std: {np.std(write):.3f})")
plt.plot(write, c="tab:red")
m, b = np.polyfit(range(len(data)), write, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:green", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Capture (RAW) - Second Attempt

# %%
with open("times_capture_raw_2.pkl", "rb") as f:
    data = pickle.load(f)
full = [sample["tf"] for sample in data]
capture = [sample["tc"] for sample in data]
dng = [sample["tdng"] for sample in data]
write = [sample["tw"] for sample in data]

# %%
plt.figure(figsize=(10,12.5))
plt.subplot(411)
plt.title("Capture (RAW) - Second Attempt")
plt.plot(full, label="All")
plt.plot(capture, label="Capture")
plt.plot(dng, label="DNG Conversion")
plt.plot(write, label="Write")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.ylim([0, None])
plt.legend()
plt.grid()
plt.subplot(412)
plt.title(f"Capture (mean: {np.mean(capture):.3f}, std: {np.std(capture):.3f})")
plt.plot(capture, c="tab:orange")
m, b = np.polyfit(range(len(data)), capture, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:blue", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(413)
plt.title(f"DNG Conversion (mean: {np.mean(dng):.3f}, std: {np.std(dng):.3f})")
plt.plot(dng, c="tab:green")
m, b = np.polyfit(range(len(data)), dng, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:red", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(414)
plt.title(f"Write (mean: {np.mean(write):.3f}, std: {np.std(write):.3f})")
plt.plot(write, c="tab:red")
m, b = np.polyfit(range(len(data)), write, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:green", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Capture (No DNG)

# %%
with open("times_capture_nodng.pkl", "rb") as f:
    data = pickle.load(f)
full = [sample["tf"] for sample in data]
capture = [sample["tc"] for sample in data]
write = [sample["tw"] for sample in data]

# %%
plt.figure(figsize=(10,10))
plt.subplot(311)
plt.title("Capture (No DNG)")
plt.plot(full, label="All")
plt.plot(capture, label="Capture")
plt.plot(write, label="Write")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.ylim([0, None])
plt.legend()
plt.grid()
plt.subplot(312)
plt.title(f"Capture (mean: {np.mean(capture):.3f}, std: {np.std(capture):.3f})")
plt.plot(capture, c="tab:orange")
m, b = np.polyfit(range(len(data)), capture, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:blue", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(313)
plt.title(f"Write (mean: {np.mean(write):.3f}, std: {np.std(write):.3f})")
plt.plot(write, c="tab:red")
m, b = np.polyfit(range(len(data)), write, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:green", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Capture (JPG)

# %%
with open("times_capture_jpg.pkl", "rb") as f:
    data = pickle.load(f)
full = [sample["tf"] for sample in data]
capture = [sample["tc"] for sample in data]
write = [sample["tw"] for sample in data]

# %%
plt.figure(figsize=(10,10))
plt.subplot(311)
plt.title("Capture (RAW)")
plt.plot(full, label="All")
plt.plot(capture, label="Capture")
plt.plot(write, label="Write")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.ylim([0, None])
plt.legend()
plt.grid()
plt.subplot(312)
plt.title(f"Capture (mean: {np.mean(capture):.3f}, std: {np.std(capture):.3f})")
plt.plot(capture, c="tab:orange")
m, b = np.polyfit(range(len(data)), capture, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:blue", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.subplot(313)
plt.title(f"Write (mean: {np.mean(write):.3f}, std: {np.std(write):.3f})")
plt.plot(write, c="tab:green")
m, b = np.polyfit(range(len(data)), write, 1)
plt.plot(m*np.array(range(len(data)))+b, c="tab:red", ls="--", label="Linear Fit")
plt.ylabel("Time (s)")
plt.xlim([0, None])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
